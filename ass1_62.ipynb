# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/Users/ommukundushir/Desktop/demo.csv')
df.head()
# Out:
#     Party                 Name    Type  \
# 0     CPI           Aziz Pasha  Others
# 1  CPI(M)     V K Ramachandran  Others
# 2     INC   Dr. Manmohan Singh  Others
# 3     INC  Dr. Manda Jagnathan  Others
# 4     INC     Prof. K.V.Thomas  Others
#
#                                              Address PAN Given  \
# 0                  16-B, Ferozeshah Road New Delhi-1         Y
# 1  No.1, First Floor Main Road Domlur Second Stag...         Y
# 2                   3, Motilal Nehru Place New Delhi         N
# 3                        9,Firozshah Road New Delhi          N
# 4                     17,Dr.B.R.Mehta Lane New Delhi         N
#
#                 Amount                                  Contribution Mode  \
# 0    ₹ \t3,000,000.00                                                CASH
# 1   ₹ \t10,000,000.00   000037, HDFC Bank Bengaluru, Dt. 16.03.2015, 5...
# 2      ₹ \t108,000.00   Cheque, State Bank of India Parliament House N...
# ...

# %%
df.columns
# Out:
# Index(['Party', 'Name', 'Type', 'Address', 'PAN Given', 'Amount',
#        'Contribution Mode', 'Financial Year ', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of         Party                    Name    Type  \
# 0         CPI              Aziz Pasha  Others
# 1      CPI(M)        V K Ramachandran  Others
# 2         INC      Dr. Manmohan Singh  Others
# 3         INC     Dr. Manda Jagnathan  Others
# 4         INC        Prof. K.V.Thomas  Others
# ...       ...                     ...     ...
# 13568     BJP        Zydus Healthcare  Others
# 13569     BJP  Zydus Wellness Limited  Others
# 13570     BJP  Zydus Wellness Limited  Others
# 13571     BJP  Zydus Wellness Limited  Others
# 13572     NCP  Zydus Wellness -Sikkim  Others
#
#                                                  Address PAN Given  \
# 0                      16-B, Ferozeshah Road New Delhi-1         Y
# 1      No.1, First Floor Main Road Domlur Second Stag...         Y
# 2                       3, Motilal Nehru Place New Delhi         N
# 3                            9,Firozshah Road New Delhi          N
# ...

# %%
df.shape
# Out:
# (13573, 14)

# %%
df.loc[df.isna().any(axis="columns")]
# Out:
#         Party                    Name    Type  \
# 0         CPI              Aziz Pasha  Others
# 1      CPI(M)        V K Ramachandran  Others
# 2         INC      Dr. Manmohan Singh  Others
# 3         INC     Dr. Manda Jagnathan  Others
# 4         INC        Prof. K.V.Thomas  Others
# ...       ...                     ...     ...
# 13568     BJP        Zydus Healthcare  Others
# 13569     BJP  Zydus Wellness Limited  Others
# 13570     BJP  Zydus Wellness Limited  Others
# 13571     BJP  Zydus Wellness Limited  Others
# 13572     NCP  Zydus Wellness -Sikkim  Others
#
#                                                  Address PAN Given  \
# 0                      16-B, Ferozeshah Road New Delhi-1         Y
# 1      No.1, First Floor Main Road Domlur Second Stag...         Y
# 2                       3, Motilal Nehru Place New Delhi         N
# 3                            9,Firozshah Road New Delhi          N
# 4                         17,Dr.B.R.Mehta Lane New Delhi         N
# ...

# %%
df.dtypes
# Out:
# Party                 object
# Name                  object
# Type                  object
# Address               object
# PAN Given             object
# Amount                object
# Contribution Mode     object
# Financial Year        object
# Unnamed: 8           float64
# Unnamed: 9           float64
# Unnamed: 10           object
# Unnamed: 11          float64
# Unnamed: 12          float64
# Unnamed: 13           object
# dtype: object
